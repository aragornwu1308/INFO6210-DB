# %%
import tweepy
 

consumer_key = '7mt5AbHE3nu4vCXXy20wtyJ4n'  
consumer_secret = 'ElXzDciXZRgmc6UtCBunfD9ZLUTMvnZL3des12W8phhqyuhh0b'  
access_token = '1102361096005058562-dGcMETpFqE3fxxT0oP0B3Y50U2f3ip'  
access_token_secret = 'utEYryfjJSBTalTBBdjiM6LrsDsEfFUsqjJf8tkJNSc4A'  

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
 

api = tweepy.API(auth)


public_tweets = api.user_timeline('steam_games')  

for tweet in public_tweets:
    print(tweet.id)
    print(tweet.text)
    print(tweet.entities)
    print(tweet.created_at)
# Out:
# 1102996896753176576
# 🔹 DAILY DEAL 🔹 Save 60% on What Remains of Edith Finch
#
# 🔍 Learn more: https://t.co/eKWcZxaSkB
#
# #SteamDeals @A_i https://t.co/IGOzUFfa1x
# ...

# %%
public_tweets = api.user_timeline('OriginInsider')  

for tweet in public_tweets:
    print(tweet.id)
    print(tweet.text)
    print(tweet.entities)
    print(tweet.created_at)
# Out:
# 1103048819548184576
# For a limited time, you can get up to 85% off on select EA games!  https://t.co/gRajXkcgh1 https://t.co/wwlKpMv4Wq
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/gRajXkcgh1', 'expanded_url': 'http://x.ea.com/57256', 'display_url': 'x.ea.com/57256', 'indices': [67, 90]}], 'media': [{'id': 1103048817857814529, 'id_str': '1103048817857814529', 'indices': [91, 114], 'media_url': 'http://pbs.twimg.com/media/D07RDj5UYAE00B5.jpg', 'media_url_https': 'https://pbs.twimg.com/media/D07RDj5UYAE00B5.jpg', 'url': 'https://t.co/wwlKpMv4Wq', 'display_url': 'pic.twitter.com/wwlKpMv4Wq', 'expanded_url': 'https://twitter.com/OriginInsider/status/1103048819548184576/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 652, 'h': 652, 'resize': 'fit'}, 'medium': {'w': 652, 'h': 652, 'resize': 'fit'}, 'small': {'w': 652, 'h': 652, 'resize': 'fit'}}}]}
# 2019-03-05 21:45:06
# 1102267417412026369
# ...

# %%
public_tweets = api.user_timeline('Blizzard_Ent')  

for tweet in public_tweets:
    print(tweet.id)
    print(tweet.text)
    print(tweet.entities)
    print(tweet.created_at)
    print(tweet.id_str)
# Out:
# 1101182354708680704
# RT @PlayHearthstone: Keep your eyes on the skies! We're flying in a treasure trove of new features, cards, updates, and events in the Year…
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PlayHearthstone', 'name': 'Hearthstone', 'id': 1209608880, 'id_str': '1209608880', 'indices': [3, 19]}], 'urls': []}
# 2019-02-28 18:08:26
# 1101182354708680704
# 1100204605516869632
# RT @PlayOverwatch: Mobilize alongside the combat medic who made the shrewd decision to make the world a better place, one bandage... or bul…
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PlayOverwatch', 'name': 'Overwatch', 'id': 2420931980, 'id_str': '2420931980', 'indices': [3, 17]}], 'urls': []}
# 2019-02-26 01:23:13
# 1100204605516869632
# 1098660162540326913
# RT @PlayOverwatch: ⚠️ Unauthorized Access Detected...
#
# &gt; TALON FIREWALL... Bypassed
# &gt; Accessing file... [CLASSIFIED] Communications Record…
# ...

# %%
public_tweets = api.user_timeline('EpicGames')  

for tweet in public_tweets:
    print(tweet.id)
    print(tweet.text)
    print(tweet.entities)
    print(tweet.created_at)
    print(tweet.id_str)
# Out:
# 1102993435861106688
# We’re pleased to share that Shakedown: Hawaii by Vblank Entertainment will be coming to the #EpicGamesStore this sp… https://t.co/SCFCNX3ABL
# {'hashtags': [{'text': 'EpicGamesStore', 'indices': [92, 107]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/SCFCNX3ABL', 'expanded_url': 'https://twitter.com/i/web/status/1102993435861106688', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}
# 2019-03-05 18:05:02
# 1102993435861106688
# 1101497320959438849
# All agents approved to deploy. Jump in to #TheDivision2 Open Beta in the #EpicGamesStore. https://t.co/eTkouwonjG https://t.co/LzJWCj4vbH
# ...

# %%
public_tweets = api.user_timeline('GOGcom')  

for tweet in public_tweets:
    print(tweet.id)
    print(tweet.text)
    print(tweet.entities)
    print(tweet.created_at)
    print(tweet.id_str)
# Out:
# 1103016958382014464
# Here comes an OVERDOSE of features with new characters, scenarios and  endings where a turn-based battle meets exhi… https://t.co/Goy8EpbkoL
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Goy8EpbkoL', 'expanded_url': 'https://twitter.com/i/web/status/1103016958382014464', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}
# 2019-03-05 19:38:30
# 1103016958382014464
# 1103002198877847553
# When reality and fantasy gets blurred, it's up to you to find a way out.
#
# The Caligula Effect: Overdose Pre-Order|… https://t.co/f2sN3b2Gg5
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/f2sN3b2Gg5', 'expanded_url': 'https://twitter.com/i/web/status/1103002198877847553', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}
# 2019-03-05 18:39:51
# 1103002198877847553
# 1102999525550145538
# @vikingjavel @WhitePaperGames Only 4. https://t.co/sfodad2g8v
# ...

# %%
public_tweets = api.user_timeline('Tencent_WeGame')  

for tweet in public_tweets:
    print(tweet.id)
    print(tweet.text)
    print(tweet.entities)
    print(tweet.created_at)
    print(tweet.id_str)
# Out:
# 943631357934047232
# #言说WeGame 在你玩过的回合制游戏中，有哪次战斗让你印象深刻？ https://t.co/LYzzhBOQqq
# {'hashtags': [{'text': '言说WeGame', 'indices': [0, 9]}], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 943631341261688832, 'id_str': '943631341261688832', 'indices': [35, 58], 'media_url': 'http://pbs.twimg.com/media/DRhztI7UEAAK-Rd.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DRhztI7UEAAK-Rd.jpg', 'url': 'https://t.co/LYzzhBOQqq', 'display_url': 'pic.twitter.com/LYzzhBOQqq', 'expanded_url': 'https://twitter.com/Tencent_WeGame/status/943631357934047232/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 720, 'h': 405, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 720, 'h': 405, 'resize': 'fit'}}}]}
# 2017-12-20 23:57:02
# 943631357934047232
# 941360481943429120
# #言说WeGame 在游戏中，你遇见过哪些印象深刻的中国元素？ https://t.co/u7db7Dg3vA
# ...

# %%
public_tweets = api.user_timeline('UbisoftUplay')  

for tweet in public_tweets:
    print(tweet.id)
    print(tweet.text)
    
    print(tweet.created_at)
    print(tweet.id_str)
# Out:
# 1102992175506296833
# The final Episode of the Legacy of the First Blade DLC is now available on Uplay!
# https://t.co/TJJUmLP83G
# 2019-03-05 18:00:01
# 1102992175506296833
# 1102991274704023553
# @SilverXGamingHD Sorry to hear that you feel that way, We're always working on improving, hopefully you'll see that we are trying to do so!
# 2019-03-05 17:56:27
# 1102991274704023553
# 1102990873200152577
# @JackDavies20_ 😢
# 2019-03-05 17:54:51
# 1102990873200152577
# 1102990660708253701
# @MrKrisViking We look forward to hearing what you think of it when you do get it!
# 2019-03-05 17:54:00
# 1102990660708253701
# 1102990535256612864
# @idobz123 Fantastic!
# 2019-03-05 17:53:30
# 1102990535256612864
# 1102990534770085888
# @NanoPolymath We'll see you around in that case Agent Nano!
# 2019-03-05 17:53:30
# 1102990534770085888
# 1102990304490278914
# @h0b0warri0r Hey, the email was sent out by accident, you can disregard that!
# 2019-03-05 17:52:35
# 1102990304490278914
# ...

# %%
public_tweets = api.user_timeline('steam_games')  

for tweet in public_tweets:
    print(tweet.id)
# Out:
# 1103071421373116421
# 1102996896753176576
# 1102996721024430080
# 1102996406069940224
# 1102995893567991808
# 1102995568081555456
# 1102645620320296960
# 1102645317814476800
# 1102274943264317440
# 1102274942521946113
# 1101912554933227520
# 1101632784882229248
# 1101632534092238850
# 1101628748678324224
# 1101628226886000640
# 1101308576327524353
# 1101301027209273344
# 1101293479290843136
# 1101288442728775681
# 1101284495603335168

# %%
public_tweets = api.user_timeline('steam_games')  

for tweet in public_tweets:
    print(tweet.created_at)
# Out:
# 2019-03-05 23:14:55
# 2019-03-05 18:18:47
# 2019-03-05 18:18:05
# 2019-03-05 18:16:50
# 2019-03-05 18:14:48
# 2019-03-05 18:13:30
# 2019-03-04 19:02:56
# 2019-03-04 19:01:44
# 2019-03-03 18:30:00
# 2019-03-03 18:30:00
# 2019-03-02 18:30:00
# 2019-03-01 23:58:17
# 2019-03-01 23:57:18
# 2019-03-01 23:42:15
# 2019-03-01 23:40:11
# 2019-03-01 02:30:00
# 2019-03-01 02:00:00
# 2019-03-01 01:30:01
# 2019-03-01 01:10:00
# 2019-03-01 00:54:19

# %%
public_tweets = api.user_timeline('steam_games')  

for tweet in public_tweets:
    print(tweet.text)
# Out:
# 🔹 MIDWEEK MADNESS 🔹 Save 35% on Divinity: Original Sin 2 - Definitive Edition
#
# 🔍 Learn more:… https://t.co/TJhgZOkvMh
# 🔹 DAILY DEAL 🔹 Save 60% on What Remains of Edith Finch
#
# 🔍 Learn more: https://t.co/eKWcZxaSkB
#
# #SteamDeals @A_i https://t.co/IGOzUFfa1x
# 🔹 DAILY DEAL 🔹 Save 45% on Dude, Stop
#
# 🔍 Learn more: https://t.co/YhD0Nryx19
#
# #SteamDeals https://t.co/2T41vwFHnf
# 🔹 MIDWEEK MADNESS 🔹 Save 50% on Ultimate Chicken Horse
#
# 🔍 Learn more: https://t.co/pkdoVJlU1H
#
# #SteamDeals https://t.co/tzb5MCP3le
# 🔹 MIDWEEK MADNESS 🔹 Save up to 75% on the Tropico franchise!
#
# 🔍 Learn more: https://t.co/mbU9jDhMN3
#
# #SteamDeals… https://t.co/o3lhB77jSZ
# 🔹 MIDWEEK MADNESS 🔹 Save 25% on X4
#
# 🔍 Learn more: https://t.co/KDnr52jgw0…
#
# #SteamDeals @EGOSOFT https://t.co/AGL2tidO3F
# 🔹 DAILY DEAL 🔹 Save 33% on Yakuza 0
#
# 🔍 Learn more: https://t.co/Svayxzi4wK
#
# #SteamDeals @SEGA https://t.co/UYP9tzpiJf
# 🔹 DAILY DEAL 🔹 Save 60% on RUINER
#
# ...

# %%
public_tweets = api.user_timeline('steam_games')  

for tweet in public_tweets:
    print(tweet.entities)
# Out:
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/TJhgZOkvMh', 'expanded_url': 'https://twitter.com/i/web/status/1103071421373116421', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [94, 117]}]}
# ...

# %%
public_tweets = api.user_timeline('steam_games')  

for tweet in public_tweets:
    print(tweet.user)
# Out:
# User(_api=<tweepy.api.API object at 0x111893160>, _json={'id': 36803580, 'id_str': '36803580', 'name': 'Steam', 'screen_name': 'steam_games', 'location': '', 'description': 'Steam, The Ultimate Online Game Platform. Follow us here for news on the latest releases and special promotions.', 'url': 'http://t.co/HS4fLUjBIw', 'entities': {'url': {'urls': [{'url': 'http://t.co/HS4fLUjBIw', 'expanded_url': 'http://www.steampowered.com', 'display_url': 'steampowered.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 4987785, 'friends_count': 8, 'listed_count': 15326, 'created_at': 'Thu Apr 30 23:01:57 +0000 2009', 'favourites_count': 3, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8462, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/them
# ...

# %%
public_tweets = api.user_timeline('OriginInsider')  

for tweet in public_tweets:
    print(tweet.id)
# Out:
# 1103354597194686464
# 1103048819548184576
# 1102267417412026369
# 1101180269426425857
# 1100878281828519936
# 1100470619630534657
# 1100173386662047744
# 1098654801502527489
# 1098383689136787461
# 1098287005836894208
# 1097921027110105088
# 1097541281289400320
# 1097178918958690304
# 1096831636669227008
# 1096560034929041408
# 1096529615491784705
# 1096467888678944768
# 1096448850686951424
# 1096439790591832065
# 1096114534681534465

# %%
public_tweets = api.user_timeline('OriginInsider')  

for tweet in public_tweets:
    print(tweet.created_at)
# Out:
# 2019-03-06 18:00:09
# 2019-03-05 21:45:06
# 2019-03-03 18:00:06
# 2019-02-28 18:00:09
# 2019-02-27 22:00:10
# 2019-02-26 19:00:16
# 2019-02-25 23:19:10
# 2019-02-21 18:44:51
# 2019-02-21 00:47:33
# 2019-02-20 18:23:22
# 2019-02-19 18:09:05
# 2019-02-18 17:00:07
# 2019-02-17 17:00:13
# 2019-02-16 18:00:14
# 2019-02-16 00:01:00
# 2019-02-15 22:00:07
# 2019-02-15 17:54:50
# 2019-02-15 16:39:11
# 2019-02-15 16:03:11
# 2019-02-14 18:30:44

# %%
public_tweets = api.user_timeline('OriginInsider')  

for tweet in public_tweets:
    print(tweet.text)
    print('/n')
# Out:
# What have you been playing in the #OriginAccess Vault this week?  https://t.co/kF0taqtgjt https://t.co/EMk5mW9vMI
# /n
# For a limited time, you can get up to 85% off on select EA games!  https://t.co/gRajXkcgh1 https://t.co/wwlKpMv4Wq
# /n
# Amazing zipline plays make us as joyful as Pathfinder. We want to see your best ones.
#
# Origin Access Rewards:… https://t.co/vZlAtWrIKU
# /n
# Have you been wreaking havoc with @playApex Legends' recent addition?  https://t.co/IxkgDb5N4y https://t.co/WqE4DzprTT
# /n
# Have a favorite Javelin to customize? We've seen some incredible designs in @AnthemGame  https://t.co/gDCWOBRKD7 https://t.co/uuamr9tODG
# /n
# You're playing @playApex. You run into this. What do you do?  https://t.co/zhvxnXdzsH https://t.co/Tf08FHXrCV
# /n
# RT @EAStarWars: The Chosen One is making his way to #StarWarsBattlefrontII this week! Brush up on what's to come with our latest blog, here…
# /n
# ...

# %%
public_tweets = api.user_timeline('OriginInsider')  

for tweet in public_tweets:
    print(tweet.user)
    print('/n')
# Out:
# User(_api=<tweepy.api.API object at 0x111893160>, _json={'id': 260306257, 'id_str': '260306257', 'name': 'Origin', 'screen_name': 'OriginInsider', 'location': '', 'description': 'Official Origin Twitter account. For technical support, please follow @EAHelp or visit https://t.co/5xFg35b7m1.', 'url': 'https://t.co/otRwnl7jAr', 'entities': {'url': {'urls': [{'url': 'https://t.co/otRwnl7jAr', 'expanded_url': 'https://twittercounter.com/', 'display_url': 'twittercounter.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/5xFg35b7m1', 'expanded_url': 'http://help.ea.com', 'display_url': 'help.ea.com', 'indices': [87, 110]}]}}, 'protected': False, 'followers_count': 733272, 'friends_count': 103, 'listed_count': 2379, 'created_at': 'Thu Mar 03 16:32:17 +0000 2011', 'favourites_count': 428, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 48502, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_tran
# ...

# %%
public_tweets = api.user_timeline('OriginInsider')  

for tweet in public_tweets:
    print(tweet.entities)
    print('/n')
# Out:
# {'hashtags': [{'text': 'OriginAccess', 'indices': [34, 47]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/kF0taqtgjt', 'expanded_url': 'http://x.ea.com/57288', 'display_url': 'x.ea.com/57288', 'indices': [66, 89]}], 'media': [{'id': 1103354594363502592, 'id_str': '1103354594363502592', 'indices': [90, 113], 'media_url': 'http://pbs.twimg.com/media/D0_nKGJU8AAqFc6.jpg', 'media_url_https': 'https://pbs.twimg.com/media/D0_nKGJU8AAqFc6.jpg', 'url': 'https://t.co/EMk5mW9vMI', 'display_url': 'pic.twitter.com/EMk5mW9vMI', 'expanded_url': 'https://twitter.com/OriginInsider/status/1103354597194686464/photo/1', 'type': 'photo', 'sizes': {'large': {'w': 1080, 'h': 1080, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'}}}]}
# /n
# ...

# %%
public_tweets = api.user_timeline('Blizzard_Ent')  

for tweet in public_tweets:
    print(tweet.text)
    print('/n')
# Out:
# RT @PlayHearthstone: Keep your eyes on the skies! We're flying in a treasure trove of new features, cards, updates, and events in the Year…
# /n
# RT @PlayOverwatch: Mobilize alongside the combat medic who made the shrewd decision to make the world a better place, one bandage... or bul…
# /n
# RT @PlayOverwatch: ⚠️ Unauthorized Access Detected...
#
# &gt; TALON FIREWALL... Bypassed
# &gt; Accessing file... [CLASSIFIED] Communications Record…
# /n
# RT @Warcraft: Did you know that today is #LoveYourPetDay 💗?
# We'd love to see pics of your pets (both in-game and IRL). ☺️ https://t.co/6eH9…
# /n
# RT @PlayOverwatch: Bon voyage! 🇫🇷
#
# Your journey to Paris begins NOW on PC, PlayStation 4, and Xbox One. https://t.co/gwPjjbjRP6
# /n
# RT @overwatchleague: Today is the day. #OWL2019⁠ ⁠
#
# Let’s get this show on the road!
#
# Watch on https://t.co/U6dIipgQGs https://t.co/IzUH…
# /n
# ...

# %%
public_tweets = api.user_timeline('Blizzard_Ent')  

for tweet in public_tweets:
    print(tweet.user)
    print('/n')
# Out:
# User(_api=<tweepy.api.API object at 0x111893160>, _json={'id': 331908924, 'id_str': '331908924', 'name': 'Blizzard Entertainment', 'screen_name': 'Blizzard_Ent', 'location': 'Irvine, CA', 'description': 'Titles shown rated T-M. For more information, visit https://t.co/Vcih7pDaQo.   @BlizzardCS for support / @LifeatBlizzard for life at Blizzard', 'url': 'https://t.co/0hFOzeztnR', 'entities': {'url': {'urls': [{'url': 'https://t.co/0hFOzeztnR', 'expanded_url': 'http://Blizzard.com', 'display_url': 'Blizzard.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/Vcih7pDaQo', 'expanded_url': 'http://ESRB.org', 'display_url': 'ESRB.org', 'indices': [52, 75]}]}}, 'protected': False, 'followers_count': 1204084, 'friends_count': 192, 'listed_count': 3524, 'created_at': 'Fri Jul 08 22:31:26 +0000 2011', 'favourites_count': 8231, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 6937, 'lang': 'en', 'contributors_enabled': Fals
# ...

# %%
public_tweets = api.user_timeline('Blizzard_Ent')  

for tweet in public_tweets:
    print(tweet.entities)
# Out:
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PlayHearthstone', 'name': 'Hearthstone', 'id': 1209608880, 'id_str': '1209608880', 'indices': [3, 19]}], 'urls': []}
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PlayOverwatch', 'name': 'Overwatch', 'id': 2420931980, 'id_str': '2420931980', 'indices': [3, 17]}], 'urls': []}
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PlayOverwatch', 'name': 'Overwatch', 'id': 2420931980, 'id_str': '2420931980', 'indices': [3, 17]}], 'urls': []}
# {'hashtags': [{'text': 'LoveYourPetDay', 'indices': [41, 56]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Warcraft', 'name': 'World of Warcraft', 'id': 61033129, 'id_str': '61033129', 'indices': [3, 12]}], 'urls': []}
# ...
